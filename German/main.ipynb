# %%
import pandas as pd

# %%
df = pd.read_excel('../Data/dano_data_upsell (4).xlsx')
df.head()
# Out:
#    customer_id  application_id application_dttm  req_amt  req_term  \
# 0        39699            1428       2021-04-06     17.0      36.0
# 1       140628           11996       2021-05-11     67.0      24.0
# 2       122414           34857       2021-06-05    500.0      60.0
# 3        40378           94446       2021-09-08    100.0      36.0
# 4       161689          116692       2021-11-10    100.0      60.0
#
#   req_product_code  monthly_income_amt   age gender_code  car_flg  ...  \
# 0               CL                73.0  34.0           F        1  ...
# 1               CL                33.0  34.0           M        1  ...
# 2               CL                27.0  53.0           F        1  ...
# 3               CL                 7.0  28.0           F        1  ...
# 4               CL                10.0  41.0           M        1  ...
#
#    clr_rate  cc_approve_amt  agreement_id      agreement_dttm  \
# 0     0.169            47.0          1195 2021-04-06 15:41:00
# ...

# %%
df.to_csv('../Data/dano_data_upsell.csv')

# %%
pd.read_csv('../Data/dano_data_upsell.csv')
# Out:
#         Unnamed: 0  customer_id  application_id application_dttm  req_amt  \
# 0                0        39699            1428       2021-04-06     17.0
# 1                1       140628           11996       2021-05-11     67.0
# 2                2       122414           34857       2021-06-05    500.0
# 3                3        40378           94446       2021-09-08    100.0
# 4                4       161689          116692       2021-11-10    100.0
# ...            ...          ...             ...              ...      ...
# 225949      225949       202717           92220       2021-09-02    100.0
# 225950      225950       169066          116340       2021-11-09     67.0
# 225951      225951        80373          125224       2021-12-02    167.0
# 225952      225952          588          195337       2022-09-17    667.0
# 225953      225953       217428          219053       2022-11-17    500.0
#
#         req_term req_product_code  monthly_income_amt   age gender_code  ...  \
# ...
